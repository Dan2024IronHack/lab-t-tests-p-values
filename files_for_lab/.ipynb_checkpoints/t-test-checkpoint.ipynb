# %% [markdown]
# #  T-tests and P-values
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_rel`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries

import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv('ttest_machine.txt', sep=" ")
df
# Out:
#    New_machine  Old_machine
# 0         42.1         42.7
# 1         41.0         43.6
# 2         41.3         43.8
# 3         41.8         43.3
# 4         42.4         42.5
# 5         42.8         43.5
# 6         43.2         43.1
# 7         42.3         41.7
# 8         41.8         44.0
# 9         42.7         44.1

# %% [markdown]
# ### One tailed t-test
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file files_for_lab/ttest_machine.xlsx. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other?

# %% [markdown]
# #### Import dataset

# %%
# Your code here: New Machine vs Old Machine

# %%
# H0 = The new machine does not pack faster on average
# H1 = The new machine packs faster on average.

# %%
# Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient 
# evidence to show if one machine is better than the other?

# %%
st.ttest_rel(df['New_machine'], df['Old_machine'])
# Out:
# TtestResult(statistic=-3.0614273841115844, pvalue=0.013540335651632521, df=9)

# %%
##  Summary : 
### The condition would be 1 tail situation : 
### 1. pvalue > 0.05 --> Hypothesis H0 can be reject
### 2. tatistic score is negative --> Hypothesis H1 can be accepted

# %%
print('Mean New_machine is ', df.New_machine.mean())
print('Mean Old_machine is ', df.Old_machine.mean())
# Out:
# Mean New_machine is  42.14
# Mean Old_machine is  43.230000000000004

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset you have already used. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.). Use pokemon.csv

# %%
# Your code here: Pokemon data

# %%
pokemon =  pd.read_csv('pokemon.txt', sep=",")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # Your code here
    
    return results

# %%
pokemon['Type 1'].value_counts(dropna=False)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon_list = list(pokemon['Type 1'].unique())
pokemon_list
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying']

# %%
pokemon_water = pokemon[(pokemon['Type 1']=='Water')|(pokemon['Type 2']=='Water')]['Total']
pokemon_water
# Out:
# 9      314
# 10     405
# 11     530
# 12     630
# 59     320
#       ...
# 759    500
# 760    320
# 762    330
# 763    500
# 799    600
# Name: Total, Length: 126, dtype: int64

# %%
def create_type_dataframes(df):
    type_dataframes = {}
    unique_types = pokemon['Type 1'].unique()
    
    for t in unique_types:
        type_dataframes[t] = pokemon[pokemon['Type 1'] == t].copy()
    
    return type_dataframes

# Use the function
type_dataframes = create_type_dataframes(df)

# # Print example results
# for type_name, type_df in type_dataframes.items():
#     print(f"DataFrame for Type '{type_name}':\n{type_df}\n")

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # Your code here
    for i in features:
        results[i]=st.ttest_ind(s1[i], s2[i], equal_var=False)[1]
    
    return results

# %%
sample_1 = pokemon[pokemon.Legendary==True].sample(30)
sample_1
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 424  383  GroudonPrimal Groudon    Ground      Fire    770  100     180
# 792  716                Xerneas     Fairy       NaN    680  126     131
# 427  385                Jirachi     Steel   Psychic    600  100     100
# 541  484                 Palkia     Water    Dragon    680   90     120
# 543  486              Regigigas    Normal       NaN    670  110     160
# 416  379              Registeel     Steel       NaN    580   80      75
# 414  377               Regirock      Rock       NaN    580   80     100
# 537  480                   Uxie   Psychic       NaN    580   75      75
# 430  386    DeoxysDefense Forme   Psychic       NaN    600   50      70
# 706  643               Reshiram    Dragon      Fire    680  100     120
# 164  150    MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 551  492       ShayminSky Forme     Grass    Flying    600  100     103
# ...

# %%
sample_2 = pokemon[pokemon.Legendary==False].sample(30)
sample_2
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 291  268                  Cascoon       Bug       NaN    205   50      35
# 501  451                  Skorupi    Poison       Bug    330   40      50
# 505  455                Carnivine     Grass       NaN    454   74     100
# 36    31                Nidoqueen    Poison    Ground    505   90      92
# 477  429                Mismagius     Ghost       NaN    495   60      60
# 371  339                 Barboach     Water    Ground    288   50      48
# 283  260    SwampertMega Swampert     Water    Ground    635  100     150
# 741  673                   Gogoat     Grass       NaN    531  123     100
# 61    56                   Mankey  Fighting       NaN    305   40      80
# 202  187                   Hoppip     Grass    Flying    250   35      35
# 132  123                  Scyther       Bug    Flying    500   70     110
# 436  391                 Monferno      Fire  Fighting    405   64      78
# ...

# %%
# Your code here
t_test_features(sample_1, sample_2)
# Out:
# {'HP': 0.000506098059945687,
#  'Attack': 2.3331586878211194e-05,
#  'Defense': 1.3934068253625151e-05,
#  'Sp. Atk': 3.7376530463734227e-07,
#  'Sp. Def': 1.0775199301410796e-06,
#  'Speed': 5.133347857719683e-05,
#  'Total': 2.3977152959748314e-10}

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here

# %%
generation_1 = pokemon[pokemon.Generation==1].sample(30)
generation_1
# Out:
#        #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 158  146     Moltres      Fire   Flying    580   90     100       90      125
# 85    79    Slowpoke     Water  Psychic    315   90      65       65       40
# 142  131      Lapras     Water      Ice    535  130      85       80       85
# 120  112      Rhydon    Ground     Rock    485  105     130      120       45
# 65    60     Poliwag     Water      NaN    300   40      50       40       40
# 55    50     Diglett    Ground      NaN    265   10      55       25       35
# 92    85      Dodrio    Normal   Flying    460   60     110       70       60
# 101   94      Gengar     Ghost   Poison    500   60      65       60      130
# 98    91    Cloyster     Water      Ice    525   50      95      180       85
# 114  106   Hitmonlee  Fighting      NaN    455   50     120       53       35
# 153  142  Aerodactyl      Rock   Flying    515   80     105       65       60
# ...

# %%
generation_2 = pokemon[pokemon.Generation==2].sample(30)
generation_2
# Out:
#        #       Name    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 236  218     Slugma      Fire       NaN    250   40      40       40       70
# 167  153    Bayleef     Grass       NaN    405   60      62       80       63
# 234  216  Teddiursa    Normal       NaN    330   60      80       50       50
# 221  206  Dunsparce    Normal       NaN    415  100      70       70       65
# 258  239     Elekid  Electric       NaN    360   45      63       37       65
# 207  192   Sunflora     Grass       NaN    425   75      75       55      105
# 214  199   Slowking     Water   Psychic    490   95      75       80      100
# 266  247    Pupitar      Rock    Ground    410   70      84       70       65
# 189  175     Togepi     Fairy       NaN    245   35      20       65       40
# 168  154   Meganium     Grass       NaN    525   80      82      100       83
# 231  214  Heracross       Bug  Fighting    500   80     125       75       40
# ...

# %%
t_test_features(generation_1, generation_2)
# Out:
# {'HP': 0.4961733762051892,
#  'Attack': 0.19617105500931975,
#  'Defense': 0.8463511380142429,
#  'Sp. Atk': 0.9694997371711292,
#  'Sp. Def': 0.057606880769036424,
#  'Speed': 0.19422465577996936,
#  'Total': 0.8377519610889792}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# all pvalue > 0.05 so H0 is not rejected

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
# Your code here
type_1 = pokemon[pokemon['Type 2'].isnull()].sample(30)
type_1
# Out:
#        #                     Name    Type 1 Type 2  Total   HP  Attack  \
# 362  331                   Cacnea     Grass    NaN    335   50      85
# 516  465                Tangrowth     Grass    NaN    535  100     100
# 581  522                  Blitzle  Electric    NaN    295   45      60
# 262  243                   Raikou  Electric    NaN    580   90      85
# 373  341                 Corphish     Water    NaN    308   43      80
# 673  612                  Haxorus    Dragon    NaN    540   76     147
# 514  463               Lickilicky    Normal    NaN    515  110      85
# 139  129                 Magikarp     Water    NaN    200   20      10
# 543  486                Regigigas    Normal    NaN    670  110     160
# 175  161                  Sentret    Normal    NaN    215   35      46
# 430  386      DeoxysDefense Forme   Psychic    NaN    600   50      70
# 609  549                Lilligant     Grass    NaN    480   70      60
# ...

# %%
type_2 = pokemon[~pokemon['Type 2'].isnull()].sample(30)
type_2
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 203  188               Skiploom     Grass    Flying    340   55      45
# 16    13                 Weedle       Bug    Poison    195   40      35
# 695  634               Zweilous      Dark    Dragon    420   72      85
# 786  711    GourgeistLarge Size     Ghost     Grass    494   75      95
# 772  702                Dedenne  Electric     Fairy    431   67      58
# 530  478               Froslass       Ice     Ghost    480   70      80
# 651  590                Foongus     Grass    Poison    294   69      55
# 267  248              Tyranitar      Rock      Dark    600  100     134
# 782  710    PumpkabooLarge Size     Ghost     Grass    335   54      66
# 452  407               Roserade     Grass    Poison    515   60      70
# 233  215                Sneasel      Dark       Ice    430   55      95
# 641  580               Ducklett     Water    Flying    305   62      44
# ...

# %%
t_test_features(type_1, type_2)
# Out:
# {'HP': 0.2922034621802353,
#  'Attack': 0.8805948764728758,
#  'Defense': 0.9777861588294152,
#  'Sp. Atk': 0.4175409269147431,
#  'Sp. Def': 0.328856483366874,
#  'Speed': 0.4870415453282245,
#  'Total': 0.622806202449071}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# all pvalue > 0.05 so H0 is not rejected

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here
# dependent variables testing
# H0: mu_a - mu_d = 0
# H1: mu_a - mu_d != 0
# 5% significance

st.ttest_rel(pokemon['Attack'], pokemon['Defense'])
# Out:
# TtestResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05, df=799)

# %%
# dependent variables testing
# H0: mu_spa - mu_spd = 0
# H1: mu_spa - mu_spd != 0
# 5% significance

st.ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])
# Out:
# TtestResult(statistic=0.853986188453353, pvalue=0.3933685997548122, df=799)

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# Attack vs Defense --> pvalue < 0.05 --> H0 rejected
# Sp Attack vs Sp Defense --> pvalue > 0.05 --> H0 cannot be rejected
